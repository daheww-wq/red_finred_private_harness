# %% [markdown]
# ### step1 process
# - 목적: 사이버 시나리오 설계
# - 입력: 쿼리 / 청크 / 스키마 (코드 내부에서 자동 입력됨)
# - 출력: 시나리오 / 프롬프트

# %%
import os
os.chdir('..')
from src.Step2_build import ScenarioGenerator

# %% [markdown]
# ### 변수 세팅

# %%
project_root = os.path.abspath(".")
output_path = f"{project_root}/tests/outputs/scenario"

# %% [markdown]
# ### 파이프라인 불러오기

# %%
step1_runner = ScenarioGenerator(
    project_root=project_root,
    output_path=output_path,
    category_name="R1_1",
    api_key=os.getenv("OPENAI_API_KEY"),
    model_name="gpt-4.1-mini" # gpt 계열
)

# %% [markdown]
# ### 실행

# %%
step1_runner.run("R1_1")
# Out:
# --- R1_1 시나리오 생성 시작 ---
# ...
# [R1_1] 쿼리별 생성: 100%|██████████| 25/25 [03:45<00:00,  9.02s/it]
# --- R1_1 시나리오 생성 완료 ---
